# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/data.csv')

# %%
data.head()
# Out:
#    current day week day month  day  year protein carbs  fat calories intake  \
# 0            1      Fri   Dec   30  2022    108g  118g  66g            1767
# 1            2      Sat   Dec   31  2022     96g  233g  70g            1908
# 2            3      Sun   Jan    1  2023    120g  155g  86g            1862
# 3            4      Mon   Jan    2  2023    126g  116g  74g            1793
# 4            5     Tues   Jan    3  2023    156g  125g  76g            1805
#
#   water move cal training day
# 0    3L      594        upper
# 1    3L      572        lower
# 2    3L        0         rest
# 3    3L      662        lower
# 4    3L      653       upper

# %%
current_day_of_progress = data["current day"]
week_day = data["week day"]
month = data["month"]
year = data["year"]
day = data["day"]
protein = data["protein"]
carbs = data["carbs"]
fat = data["fat"]
calories_intake = data["calories intake"]
dwater = data["water"]
move_cal = data["move cal"]
type_of_training = data["training day"]

# %%
data.sort_values(by=['move cal'])
# Out:
#     current day week day month  day  year protein    carbs   fat  \
# 2             3      Sun   Jan    1  2023    120g     155g   86g
# 6             7     Thur   Jan    5  2023     96g     126g   88g
# 1             2      Sat   Dec   31  2022     96g     233g   70g
# 0             1      Fri   Dec   30  2022    108g     118g   66g
# 5             6      Wed   Jan    4  2023    157g     161g   61g
# 4             5     Tues   Jan    3  2023    156g     125g   76g
# 3             4      Mon   Jan    2  2023    126g     116g   74g
# 7             8      Fri   Jan    6  2023    148g     118g   79g
# 8             9      Sat   Jan    7  2023    155g     128g   73g
# 10           11      Mon   Jan    9  2023    133g     137g   63g
# 9            10      Sun   Jan    8  2023    254g  127g73g  1707
#
#    calories intake water move cal training day
# 2             1862    3L        0         rest
# 6             1759    3L        0         rest
# 1             1908    3L      572        lower
# 0             1767    3L      594        upper
# 5             1815    3L      614        lower
# 4             1805    3L      653       upper
# 3             1793    3L      662        lower
# 7             1683    3L      677        upper
# 8             1703    3L      684        lower
# 10            1456    3L      802        lower
# 9               3L   812    upper          NaN

# %%
fig, ax = plt.subplots(figsize=(14,6))
plt.title('Moving calories')
plt.ylabel('move cal')
plt.xlabel('current days')

ax.bar(current_day_of_progress, move_cal, width=1, edgecolor="black", linewidth=0.7)
# Out:
# <BarContainer object of 11 artists>
