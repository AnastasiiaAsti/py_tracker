# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/data.csv')

# %%
data.head()
# Out:
#    current day week day month  day  year  protein  carbs  fat  \
# 0            1      Fri   Dec   30  2022      108    118   66
# 1            2      Sat   Dec   31  2022       96    233   70
# 2            3      Sun   Jan    1  2023      120    155   86
# 3            4      Mon   Jan    2  2023      126    116   74
# 4            5     Tues   Jan    3  2023      156    125   76
#
#    calories intake water  move cal training day
# 0             1767    3L       594        upper
# 1             1908    3L       572        lower
# 2             1862    3L         0         rest
# 3             1793    3L       662        lower
# 4             1805    3L       653       upper

# %%
current_day_of_progress = data["current day"]
week_day = data["week day"]
month = data["month"]
year = data["year"]
day = data["day"]
protein = data["protein"]
carbs = data["carbs"]
fat = data["fat"]
calories_intake = data["calories intake"]
dwater = data["water"]
move_cal = data["move cal"]
type_of_training = data["training day"]

# %%
data.sort_values(by=['move cal'])
# Out:
#     current day week day month  day  year  protein  carbs  fat  \
# 2             3      Sun   Jan    1  2023      120    155   86
# 6             7     Thur   Jan    5  2023       96    126   88
# 1             2      Sat   Dec   31  2022       96    233   70
# 0             1      Fri   Dec   30  2022      108    118   66
# 5             6      Wed   Jan    4  2023      157    161   61
# 4             5     Tues   Jan    3  2023      156    125   76
# 3             4      Mon   Jan    2  2023      126    116   74
# 7             8      Fri   Jan    6  2023      148    118   79
# 8             9      Sat   Jan    7  2023      155    128   73
# 10           11      Mon   Jan    9  2023      133    137   63
# 9            10      Sun   Jan    8  2023      254    127   73
#
#     calories intake water  move cal training day
# 2              1862    3L         0         rest
# 6              1759    3L         0         rest
# 1              1908    3L       572        lower
# 0              1767    3L       594        upper
# 5              1815    3L       614        lower
# 4              1805    3L       653       upper
# 3              1793    3L       662        lower
# 7              1683    3L       677        upper
# 8              1703    3L       684        lower
# 10             1456    3L       802        lower
# 9              1707    3L       812        upper

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.bar(current_day_of_progress, move_cal, width=1, edgecolor="black", color="grey", linewidth=0.7)

font = {
    'size': 18,
    'fontweight': 'bold'
}

title = {
    'size': 23,
    'fontweight': 'bold',
}

# set daily goal
plt.axhline(y = 500, color = 'r', linestyle = '--')

plt.title('Moving calories', fontdict = title)
plt.ylabel('move cal', fontdict = font) 
plt.xlabel('current days', fontdict = font)
# Out:
# Text(0.5, 0, 'current days')

# %%
fig, ax = plt.subplots(figsize=(16,8))
x = np.arange(len(current_day_of_progress))


width = 0.2
plt.bar(x-0.2, protein,
        width, color='red', label='protein')
plt.bar(x, carbs,
        width, color='green', label='carbs')
plt.bar(x+0.2, fat,
        width, color='gold', label='fat')

plt.axhline(y = 73, color='gold', linestyle = '--')
plt.axhline(y = 142, color='green', linestyle = '--')
plt.axhline(y = 165, color='red', linestyle = '--')

plt.title('Macros', fontdict = title)
plt.legend(fontsize=15)
plt.ylabel('gramms per day', fontdict = font)
# Out:
# Text(0, 0.5, 'gramms per day')
